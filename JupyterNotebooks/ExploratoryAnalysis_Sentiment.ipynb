# %% [markdown]
# Importing all necesary libraries with the respective configuration

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Stablishing the file path for local environment

# %%
count_file = r"C:\Users\aefig\OneDrive\Escritorio\Tec\07_6to Trimestre\02_ProyectoIntegrador\NewsRegisterSentiment.csv"

# %% [markdown]
# Loading teh Data Frame using pandas

# %%
df = pd.read_csv(count_file)

# %% [markdown]
# Showing the Data Frame Size in the format (rows, columns)

# %%
df.shape
# Out:
# (1220, 504)

# %% [markdown]
# Stablishing some importan information such as the first/last day in the register, as well as the number of symbols and the total amount of days

# %%
print(f"First register date: {df.head(1).iloc[0,0]}")
print(f"Last register date: {df.tail(1).iloc[0,0]}")
print(f"Total symbols: {df.shape[1]-1}")
print(f"Total registers: {df.shape[0]}")
# Out:
# First register date: 01-01-21
# Last register date: 04-05-24
# Total symbols: 503
# Total registers: 1220

# %% [markdown]
# Analysing the presentation for each data. In this case the analysis is made based in the number of news registerd by day for each symbol

# %%
df.head()
# Out:
#        Date       MMM       AOS       ABT      ABBV       ACN      ADBE  \
# 0  01-01-21  0.845974  0.000000 -3.528527  0.000000  0.000000 -1.865247
# 1  02-01-21  0.641352  0.000000 -0.744283  0.000000 -0.984547  0.001489
# 2  03-01-21 -4.969623  0.000000 -2.634179 -3.789056 -1.981866 -3.894657
# 3  04-01-21  0.878635  0.000000  2.411639 -3.788457  0.967256 -3.924308
# 4  05-01-21  2.635330  0.999395  0.443678  0.013348  0.334767 -4.920545
#
#         AMD       AES  AFL         A       APD      ABNB      AKAM       ALB  \
# 0  1.085387  0.000000  0.0 -1.955151  0.998763 -0.996694  0.000000 -0.998413
# 1 -0.960088  0.000000  0.0 -0.994954  1.017371 -0.991516  0.000000 -0.998413
# 2 -2.964449  1.010417  0.0 -0.978989  0.973397 -0.986406  0.000000 -0.001303
# 3  0.993459  0.451147  0.0 -0.978989 -2.932807  0.448108 -0.003898 -0.978643
# 4 -1.983299 -0.009824  0.0  0.970843 -4.849309  2.031876 -0.997856 -0.977340
#
# ...

# %% [markdown]
# Exploring the total entries and the data types for the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Columns: 504 entries, Date to ZTS
# dtypes: float64(503), object(1)
# memory usage: 4.7+ MB

# %% [markdown]
# Using describe to anayse the main metrics for each symbol

# %%
df.describe()
# Out:
#                MMM          AOS          ABT         ABBV          ACN  \
# count  1220.000000  1220.000000  1220.000000  1220.000000  1220.000000
# mean     -0.201452     0.426912     0.226813    -0.311928     1.761424
# std       2.035169     1.251942     1.958030     1.666847     1.937433
# min      -4.994021    -4.984306    -4.987375    -4.946399    -4.976583
# 25%      -1.581441     0.000000    -0.991545    -1.380516     0.341075
# 50%      -0.011534     0.000000     0.068925    -0.011854     1.981841
# 75%       1.022205     0.998448     1.674495     0.912919     3.000467
# max       4.992574     4.990989     4.976196     4.871593     4.995995
#
#               ADBE          AMD          AES          AFL            A  \
# count  1220.000000  1220.000000  1220.000000  1220.000000  1220.000000
# mean      0.243336    -0.265139     0.134214     0.228040     0.259881
# std       2.008300     1.899411     1.366338     1.283692     1.548489
# ...

# %% [markdown]
# Transpose to explore data based on the metrics

# %%
df_d = df.describe().T

# %% [markdown]
# Top Symbols with more news

# %%
df_d.sort_values(by=['mean'], ascending=False).head(15)
# Out:
#        count      mean        std       min       25%       50%       75%  \
# MAR   1220.0  2.541931   1.793339 -4.888341  1.301006  2.978571  3.984601
# HLT   1220.0  2.263029   1.809786 -4.767392  1.005460  2.502415  3.807288
# ROK   1220.0  2.049961  28.613356 -4.680032  0.000000  0.998764  2.034477
# ZBH   1220.0  1.932028  40.440282 -4.720386 -0.166805  0.000000  0.996750
# ACN   1220.0  1.761424   1.937433 -4.976583  0.341075  1.981841  3.000467
# ODFL  1220.0  1.689433   1.948875 -4.915849  0.532743  1.836217  2.997347
# PODD  1220.0  1.588460  40.442581 -4.984887  0.000000  0.000000  0.000000
# EL    1220.0  1.583952   1.940788 -4.968754  0.028051  1.806224  2.992167
# LYV   1220.0  1.523626   2.199988 -4.973747  0.000000  1.814561  2.997133
# HSY   1220.0  1.502258   1.973373 -4.989348  0.063172  1.831183  2.971720
# CTSH  1220.0  1.409661   1.994398 -4.993615  0.009604  1.213141  2.963753
# FSLR  1220.0  1.322470   1.970942 -4.907631  0.003744  1.370471  2.897833
# ...

# %%
df_d.sort_values(by=['mean'], ascending=False).head(15).index
# Out:
# Index(['MAR', 'HLT', 'ROK', 'ZBH', 'ACN', 'ODFL', 'PODD', 'EL', 'LYV', 'HSY',
#        'CTSH', 'FSLR', 'SHW', 'RCL', 'OMC'],
#       dtype='object')

# %%
df["MAR"].hist()
# Out:
# <AxesSubplot:>

# %%
df.plot(x='Date', y='MAR')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Top Symbols with less news

# %%
df_d.sort_values(by=['mean'], ascending=True).head(15)
# Out:
#        count      mean       std       min       25%       50%       75%  \
# VTR   1220.0 -3.731528  1.184123 -4.949938 -4.841276 -3.906855 -2.946427
# MRK   1220.0 -2.753993  0.961259 -4.982519 -2.998465 -2.995606 -2.336487
# CTAS  1220.0 -2.442587  2.102348 -4.981649 -3.976494 -2.979400 -0.990974
# AIZ   1220.0 -2.117337  1.718966 -4.864148 -3.632538 -2.430452 -0.554811
# DLTR  1220.0 -1.668336  1.855447 -4.993551 -2.972206 -1.948779 -0.269878
# PFE   1220.0 -1.634519  1.680246 -4.988486 -2.946247 -1.849059 -0.320279
# TSLA  1220.0 -1.618738  1.716104 -4.988315 -2.968634 -1.880603 -0.287490
# DG    1220.0 -1.571060  1.923604 -4.991217 -2.967391 -1.794021 -0.159598
# UBER  1220.0 -1.562523  1.832859 -4.980515 -2.961098 -1.923775 -0.172479
# NSC   1220.0 -1.418924  2.136014 -4.993990 -2.963282 -1.399990  0.008111
# T     1220.0 -1.340061  1.819518 -4.988980 -2.898147 -1.114454 -0.016420
# META  1220.0 -1.276062  1.856744 -4.992710 -2.760935 -1.240707  0.000000
# ...

# %%
df_d.sort_values(by=['mean'], ascending=True).head(15).index
# Out:
# Index(['VTR', 'MRK', 'CTAS', 'AIZ', 'DLTR', 'PFE', 'TSLA', 'DG', 'UBER', 'NSC',
#        'T', 'META', 'WMT', 'AAPL', 'MRNA'],
#       dtype='object')

# %%
df["VTR"].hist()
# Out:
# <AxesSubplot:>

# %%
df.plot(x='Date', y='VTR')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Showing all the symbols

# %%
symbols = df.columns[1:]
symbols
# Out:
# Index(['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A',
#        ...
#        'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZTS'],
#       dtype='object', length=503)

# %% [markdown]
# Showing distribution where the distribution is not baised to max or min

# %%
df_d[(df_d['max'] != df_d['75%']) & (df_d['75%'] != df_d['50%']) & (df_d['50%'] != df_d['25%']) & (df_d['25%'] != df_d['min'])].head()
# Out:
#        count      mean       std       min       25%       50%       75%  \
# MMM   1220.0 -0.201452  2.035169 -4.994021 -1.581441 -0.011534  1.022205
# ABT   1220.0  0.226813  1.958030 -4.987375 -0.991545  0.068925  1.674495
# ABBV  1220.0 -0.311928  1.666847 -4.946399 -1.380516 -0.011854  0.912919
# ACN   1220.0  1.761424  1.937433 -4.976583  0.341075  1.981841  3.000467
# ADBE  1220.0  0.243336  2.008300 -4.991618 -1.000428  0.070603  1.846132
#
#            max
# MMM   4.992574
# ABT   4.976196
# ABBV  4.871593
# ACN   4.995995
# ADBE  4.991703

# %%
df["MMM"].hist()
# Out:
# <AxesSubplot:>

# %%
df.plot(x='Date', y='AES')
# Out:
# <AxesSubplot:xlabel='Date'>
